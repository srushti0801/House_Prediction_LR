# %%
import numpy as np 
import pandas as pd #panel dataframe
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\Srushti\\Desktop\\ML\\USA_Housing.csv",encoding='latin-1')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
df.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
df.tail(5)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population        Price
# 4995                          3.46      22837.36103  1060193.786
# 4996                          4.02      25616.11549  1482617.729
# 4997                          2.13      33266.14549  1030729.583
# 4998                          5.44      42625.62016  1198656.872
# 4999                          4.07      46501.28380  1298950.480

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %%
df.isnull().sum() #to check for null values
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
import Srushti_statistics

# %%
for col_name in df.columns:
    Srushti_statistics.cal_stats(col_name,df[col_name])
    print('-'*100)
# Out:
# Avg. Area Income
# Total Sum 342915544.91985
# Total Count 5000
# Minimum 17796.63119
# Maximum 107701.7484
# Range 89905.12
# Average 68583.11
# Median 68804.29
# Mode ModeResult(mode=17796.63119, count=1)
# Q1 61480.56239
# Q3 75783.33866499999
# IQR 14302.77627499999
# Lower Whisker 40026.39797750002
# Upper Whisker 97237.50307749998
# Variance 113570058.15998553
# Standard Deviation 10656.92536147202
# Skewness -0.03370985850476661
# Kurtosis 0.044328500390600656
# ----------------------------------------------------------------------------------------------------
# Avg. Area House Age
# Total Sum 29886.110176435002
# Total Count 5000
# Minimum 2.644304186
# Maximum 9.519088066
# Range 6.87
# Average 5.98
# Median 5.97
# Mode ModeResult(mode=2.644304186, count=1)
# Q1 5.32228301575
# Q3 6.65080847925
# IQR 1.3285254635000001
# Lower Whisker 3.3294948205
# Upper Whisker 8.6435966745
# Variance 0.9827887594565952
# Standard Deviation 0.9913570292566625
# ...

# %%
for col_name in df.columns:
    print(col_name)
    sns.displot(df[col_name])
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
for col_name in df.columns:
    print(col_name)
    sns.kdeplot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
for col_name in df.columns:
    print(col_name)
    sns.violinplot(df[col_name])
    plt.show()
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',vmin=-1,vmax=1)
plt.show()

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
#CROSS VALIDATION
#dividing data in two types
# TRaining data = x&y
# TESTING data x
# PREDICTION TEST

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
len(x)
# Out:
# 5000

# %%
len(y)
# Out:
# 5000

# %%
len(x_train)
# Out:
# 4000

# %%
len(x_test)
# Out:
# 1000

# %%
len(y_train)
# Out:
# 4000

# %%
len(y_test)
# Out:
# 1000

# %%
x_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3894       60685.92640             6.240501                   7.151435
# 4651       66057.18199             4.067166                   7.741793
# 4479       62303.11302             5.231732                   8.454275
# 4122       57072.75343             5.644447                   7.738073
# 1500       61460.93949             6.682596                   7.400038
# ...                ...                  ...                        ...
# 964        48357.06347             4.727646                   7.989516
# 1566       73649.39696             6.471256                   5.667117
# 1657       48510.91013             6.410977                   4.729554
# 4588       68377.38138             5.206022                   5.744060
# 3854       70030.02061             6.223012                   7.656969
#
#       Avg. Area Number of Bedrooms  Area Population
# 3894                          6.12      27530.56599
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
#5 m slope
#1 c y-intercept
#y = price
#y = m1x1+m2x2+m3x3+m4x4+m5x5+c

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([2.15880005e+01, 1.65087853e+05, 1.20537079e+05, 2.46209300e+03,
#        1.52309694e+01])

# %%
lr.intercept_
# Out:
# -2637426.076856173

# %%
y_pred=lr.predict(x_test)

# %%
#sum of squared error
sse=sum((y_pred-y_test)**2)
print('Sum of Squared Error',sse)

#mean squared error
mse=sum((y_pred-y_test)**2)/1000
print('Mean Squared Error',mse)


#root mean squared error
rmse=np.sqrt(sum((y_pred-y_test)**2)/1000)
print('Root Mean Squared Error',rmse)
# Out:
# Sum of Squared Error 9987859558649.78
# Mean Squared Error 9987859558.649778
# Root Mean Squared Error 99939.27935826723

# %%
df['Price'].mean()
# Out:
# 1232072.6541453

# %%
sns.displot(y_pred-y_test)
